# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Airbnb_Open_Data.csv')
# Out:
# C:\Users\khair\AppData\Local\Temp\ipykernel_13768\2167922700.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Airbnb_Open_Data.csv')

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df['id'].duplicated().value_counts()
# Out:
# id
# False    102058
# True        541
# Name: count, dtype: int64

# %%
df = df.drop_duplicates(subset=['id'])

# %%
df['id'].duplicated().value_counts()
# Out:
# id
# False    102058
# Name: count, dtype: int64

# %%
df['NAME']
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                                                      NaN
# 4         Entire Apt: Spacious Studio/Loft by central park
#                                 ...
# 102053                 Cozy bright room near Prospect Park
# 102054           Private Bedroom with Amazing Rooftop View
# 102055       Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056          Room & private bathroom in historic Harlem
# 102057                                     Rosalee Stewart
# Name: NAME, Length: 102058, dtype: object

# %%
df['NAME'] = df['NAME'].str.replace('  ', '')
# Out:
# C:\Users\khair\AppData\Local\Temp\ipykernel_13768\640686949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NAME'] = df['NAME'].str.replace('  ', '')

# %%
df['NAME']
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                                                      NaN
# 4         Entire Apt: Spacious Studio/Loft by central park
#                                 ...
# 102053                 Cozy bright room near Prospect Park
# 102054           Private Bedroom with Amazing Rooftop View
# 102055       Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056          Room & private bathroom in historic Harlem
# 102057                                     Rosalee Stewart
# Name: NAME, Length: 102058, dtype: object

# %%
df = df.dropna(subset = ['NAME'])

# %%
df['NAME'] = df['NAME'].str.replace(r'[@, #, $, %, !, *, &]', ' ', regex = True)

# %%
df['NAME'] = df['NAME'].str.replace(' ', '')

# %%
df['NAME']
# Out:
# 0                         Cleanquietapthomebythepark
# 1                                SkylitMidtownCastle
# 2                      THEVILLAGEOFHARLEM....NEWYORK
# 4         EntireApt:SpaciousStudio/Loftbycentralpark
# 5                 LargeCozy1BRApartmentInMidtownEast
#                              ...
# 102053                CozybrightroomnearProspectPark
# 102054          PrivateBedroomwithAmazingRooftopView
# 102055        PrettyBrooklynOne-Bedroomfor2to4people
# 102056           RoomprivatebathroominhistoricHarlem
# 102057                                RosaleeStewart
# Name: NAME, Length: 101808, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101808 entries, 0 to 102057
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101808 non-null  int64
#  1   NAME                            101808 non-null  object
#  2   host id                         101808 non-null  int64
#  3   host_identity_verified          101531 non-null  object
#  4   host name                       101410 non-null  object
#  5   neighbourhood group             101781 non-null  object
#  6   neighbourhood                   101792 non-null  object
#  7   lat                             101800 non-null  float64
#  8   long                            101800 non-null  float64
#  9   country                         101281 non-null  object
#  10  country code                    101685 non-null  object
#  11  instant_bookable                101711 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               277
# host name                            398
# neighbourhood group                   27
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              527
# country code                         123
# instant_bookable                      97
# cancellation_policy                   71
# room type                              0
# Construction year                    205
# price                                244
# service fee                          273
# minimum nights                       394
# number of reviews                    182
# last review                        15796
# reviews per month                  15782
# review rate number                   311
# calculated host listings count       318
# ...

# %%
df['host id']
# Out:
# 0         80014485718
# 1         52335172823
# 2         78829239556
# 4         92037596077
# 5         45498551794
#              ...
# 102053    77326652202
# 102054    45936254757
# 102055    23801060917
# 102056    15593031571
# 102057    93578954226
# Name: host id, Length: 101808, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101808 entries, 0 to 102057
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101808 non-null  int64
#  1   NAME                            101808 non-null  object
#  2   host id                         101808 non-null  int64
#  3   host_identity_verified          101531 non-null  object
#  4   host name                       101410 non-null  object
#  5   neighbourhood group             101781 non-null  object
#  6   neighbourhood                   101792 non-null  object
#  7   lat                             101800 non-null  float64
#  8   long                            101800 non-null  float64
#  9   country                         101281 non-null  object
#  10  country code                    101685 non-null  object
#  11  instant_bookable                101711 non-null  object
# ...

# %%
df['host id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset = ['host id'])

# %%
df['host id']
# Out:
# 0         80014485718
# 1         52335172823
# 2         78829239556
# 4         92037596077
# 5         45498551794
#              ...
# 102053    77326652202
# 102054    45936254757
# 102055    23801060917
# 102056    15593031571
# 102057    93578954226
# Name: host id, Length: 101808, dtype: int64

# %%
df['host name'].duplicated().value_counts()
# Out:
# host name
# True     88624
# False    13184
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               277
# host name                            398
# neighbourhood group                   27
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              527
# country code                         123
# instant_bookable                      97
# cancellation_policy                   71
# room type                              0
# Construction year                    205
# price                                244
# service fee                          273
# minimum nights                       394
# number of reviews                    182
# last review                        15796
# reviews per month                  15782
# review rate number                   311
# calculated host listings count       318
# ...

# %%
df['host name'].value_counts()
# Out:
# host name
# Michael             877
# David               759
# John                576
# Alex                541
# Sonder (NYC)        515
#                    ...
# Evrim                 1
# Nathanael             1
# Serkan                1
# Alankrit              1
# Sebastien Rafael      1
# Name: count, Length: 13183, dtype: int64

# %%
df = df.dropna(subset = ['host name'])

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               276
# host name                              0
# neighbourhood group                   26
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              526
# country code                         122
# instant_bookable                      96
# cancellation_policy                   70
# room type                              0
# Construction year                    200
# price                                239
# service fee                          268
# minimum nights                       394
# number of reviews                    182
# last review                        15717
# reviews per month                  15703
# review rate number                   307
# calculated host listings count       318
# ...

# %%
df['host name'] = df['host name'].str.replace(r'[@ , #,  $,  %,  &,  *,  !,  ?, _,  -,  +,  =,  ( ),  [, ],  {, },  /,  \,  |,  ., :,  ;,  " ]', '', regex = True)

# %%
df['host name'].value_counts()
# Out:
# host name
# Michael             877
# David               759
# John                576
# Alex                541
# Sonder (NYC)        515
#                    ...
# Evrim                 1
# Nathanael             1
# Serkan                1
# Alankrit              1
# Sebastien Rafael      1
# Name: count, Length: 13183, dtype: int64

# %%
df['host name'] = df['host name'].str.replace(' ', '')

# %%
df
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 2        1002403               THEVILLAGEOFHARLEM....NEWYORK  78829239556
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# ...          ...                                         ...          ...
# 102053  57365208              CozybrightroomnearProspectPark  77326652202
# 102054  57365760        PrivateBedroomwithAmazingRooftopView  45936254757
# 102055  57366313      PrettyBrooklynOne-Bedroomfor2to4people  23801060917
# 102056  57366865         RoomprivatebathroominhistoricHarlem  15593031571
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
df['neighbourhood'].duplicated().sum()
# Out:
# np.int64(101185)

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               276
# host name                              0
# neighbourhood group                   26
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              526
# country code                         122
# instant_bookable                      96
# cancellation_policy                   70
# room type                              0
# Construction year                    200
# price                                239
# service fee                          268
# minimum nights                       394
# number of reviews                    182
# last review                        15717
# reviews per month                  15703
# review rate number                   307
# calculated host listings count       318
# ...

# %%
df['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'East Harlem', 'Murray Hill',
#        'Bedford-Stuyvesant', "Hell's Kitchen", 'Upper West Side',
#        'Chinatown', 'South Slope', 'West Village', 'Williamsburg',
#        'Fort Greene', 'Chelsea', 'Crown Heights', 'Park Slope',
#        'Windsor Terrace', 'Inwood', 'East Village', 'Greenpoint',
#        'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'Clinton Hill', 'Washington Heights', 'Upper East Side',
#        'Woodside', 'Brooklyn Heights', 'Prospect Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
#        'Little Italy', 'East Flatbush', 'Tompkinsville', 'Astoria',
# ...

# %%
df = df.dropna(subset = ['neighbourhood'])

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df['lat'].duplicated().sum()
# Out:
# np.int64(79442)

# %%
df = df[df['lat'] > -90]

# %%
df
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 2        1002403               THEVILLAGEOFHARLEM....NEWYORK  78829239556
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# ...          ...                                         ...          ...
# 102053  57365208              CozybrightroomnearProspectPark  77326652202
# 102054  57365760        PrivateBedroomwithAmazingRooftopView  45936254757
# 102055  57366313      PrettyBrooklynOne-Bedroomfor2to4people  23801060917
# 102056  57366865         RoomprivatebathroominhistoricHarlem  15593031571
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
df = df[df['lat'] < 90]

# %%
df
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 2        1002403               THEVILLAGEOFHARLEM....NEWYORK  78829239556
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# ...          ...                                         ...          ...
# 102053  57365208              CozybrightroomnearProspectPark  77326652202
# 102054  57365760        PrivateBedroomwithAmazingRooftopView  45936254757
# 102055  57366313      PrettyBrooklynOne-Bedroomfor2to4people  23801060917
# 102056  57366865         RoomprivatebathroominhistoricHarlem  15593031571
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
df = df[df['long'] > -180]

# %%
df
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 2        1002403               THEVILLAGEOFHARLEM....NEWYORK  78829239556
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# ...          ...                                         ...          ...
# 102053  57365208              CozybrightroomnearProspectPark  77326652202
# 102054  57365760        PrivateBedroomwithAmazingRooftopView  45936254757
# 102055  57366313      PrettyBrooklynOne-Bedroomfor2to4people  23801060917
# 102056  57366865         RoomprivatebathroominhistoricHarlem  15593031571
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
df = df[df['lat'] < 180]

# %%
df
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 2        1002403               THEVILLAGEOFHARLEM....NEWYORK  78829239556
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# ...          ...                                         ...          ...
# 102053  57365208              CozybrightroomnearProspectPark  77326652202
# 102054  57365760        PrivateBedroomwithAmazingRooftopView  45936254757
# 102055  57366313      PrettyBrooklynOne-Bedroomfor2to4people  23801060917
# 102056  57366865         RoomprivatebathroominhistoricHarlem  15593031571
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
df['long'].duplicated().sum()
# Out:
# np.int64(83640)

# %%
df['long'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['lat'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               276
# host name                              0
# neighbourhood group                   26
# neighbourhood                          0
# lat                                    0
# long                                   0
# country                              524
# country code                         120
# instant_bookable                      94
# cancellation_policy                   68
# room type                              0
# Construction year                    199
# price                                238
# service fee                          268
# minimum nights                       393
# number of reviews                    182
# last review                        15716
# reviews per month                  15702
# review rate number                   307
# calculated host listings count       318
# ...

# %%
#7.Clean country ,country code ,instant bookable,cancellation

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101386 entries, 0 to 102057
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101386 non-null  int64
#  1   NAME                            101386 non-null  object
#  2   host id                         101386 non-null  int64
#  3   host_identity_verified          101110 non-null  object
#  4   host name                       101386 non-null  object
#  5   neighbourhood group             101360 non-null  object
#  6   neighbourhood                   101386 non-null  object
#  7   lat                             101386 non-null  float64
#  8   long                            101386 non-null  float64
#  9   country                         100862 non-null  object
#  10  country code                    101266 non-null  object
#  11  instant_bookable                101292 non-null  object
# ...

# %%
df['country'].unique()
# Out:
# array(['United States', nan], dtype=object)

# %%
df['country'].value_counts()
# Out:
# country
# United States    100862
# Name: count, dtype: int64

# %%
df = df.dropna(subset = ['country'])

# %%
df['country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df['country code']
# Out:
# 0         US
# 1         US
# 2         US
# 4         US
# 5         US
#           ..
# 102053    US
# 102054    US
# 102055    US
# 102056    US
# 102057    US
# Name: country code, Length: 100862, dtype: object

# %%
df['country code'].unique()
# Out:
# array(['US', nan], dtype=object)

# %%
df = df.dropna(subset = ['country code'])

# %%
df['country code'].unique()
# Out:
# array(['US'], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df['instant_bookable']
# Out:
# 0         False
# 1         False
# 2          True
# 4         False
# 5          True
#           ...
# 102053     True
# 102054    False
# 102055     True
# 102056     True
# 102057    False
# Name: instant_bookable, Length: 100822, dtype: object

# %%
df['instant_bookable'].unique()
# Out:
# array([False, True], dtype=object)

# %%
df['instant_bookable'].value_counts()
# Out:
# instant_bookable
# False    50615
# True     50207
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100822 entries, 0 to 102057
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              100822 non-null  int64
#  1   NAME                            100822 non-null  object
#  2   host id                         100822 non-null  int64
#  3   host_identity_verified          100550 non-null  object
#  4   host name                       100822 non-null  object
#  5   neighbourhood group             100797 non-null  object
#  6   neighbourhood                   100822 non-null  object
#  7   lat                             100822 non-null  float64
#  8   long                            100822 non-null  float64
#  9   country                         100822 non-null  object
#  10  country code                    100822 non-null  object
#  11  instant_bookable                100822 non-null  object
# ...

# %%
df['instant_bookable'].duplicated().sum()
# Out:
# np.int64(100820)

# %%
df['cancellation_policy'].unique()
# Out:
# array(['strict', 'moderate', 'flexible'], dtype=object)

# %%
df['cancellation_policy'].value_counts()
# Out:
# cancellation_policy
# moderate    33767
# strict      33537
# flexible    33518
# Name: count, dtype: int64

# %%
df = df.drop(columns = ['country', 'country code', 'instant_bookable', 'cancellation_policy'])

# %%
df
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 2        1002403               THEVILLAGEOFHARLEM....NEWYORK  78829239556
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# ...          ...                                         ...          ...
# 102053  57365208              CozybrightroomnearProspectPark  77326652202
# 102054  57365760        PrivateBedroomwithAmazingRooftopView  45936254757
# 102055  57366313      PrettyBrooklynOne-Bedroomfor2to4people  23801060917
# 102056  57366865         RoomprivatebathroominhistoricHarlem  15593031571
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
df['room type']
# Out:
# 0            Private room
# 1         Entire home/apt
# 2            Private room
# 4         Entire home/apt
# 5         Entire home/apt
#                ...
# 102053       Private room
# 102054       Private room
# 102055    Entire home/apt
# 102056       Private room
# 102057    Entire home/apt
# Name: room type, Length: 100822, dtype: object

# %%
df['room type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100822 entries, 0 to 102057
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              100822 non-null  int64
#  1   NAME                            100822 non-null  object
#  2   host id                         100822 non-null  int64
#  3   host_identity_verified          100550 non-null  object
#  4   host name                       100822 non-null  object
#  5   neighbourhood group             100797 non-null  object
#  6   neighbourhood                   100822 non-null  object
#  7   lat                             100822 non-null  float64
#  8   long                            100822 non-null  float64
#  9   room type                       100822 non-null  object
#  10  Construction year               100627 non-null  float64
#  11  price                           100588 non-null  object
# ...

# %%
df = df.dropna(subset = ['Construction year'])

# %%
df['Construction year'] = df['Construction year'].astype('int')
# Out:
# C:\Users\khair\AppData\Local\Temp\ipykernel_13768\2074770313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Construction year'] = df['Construction year'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100627 entries, 0 to 102057
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              100627 non-null  int64
#  1   NAME                            100627 non-null  object
#  2   host id                         100627 non-null  int64
#  3   host_identity_verified          100367 non-null  object
#  4   host name                       100627 non-null  object
#  5   neighbourhood group             100605 non-null  object
#  6   neighbourhood                   100627 non-null  object
#  7   lat                             100627 non-null  float64
#  8   long                            100627 non-null  float64
#  9   room type                       100627 non-null  object
#  10  Construction year               100627 non-null  int64
#  11  price                           100397 non-null  object
# ...

# %%
df['Construction year'].unique()
# Out:
# array([2020, 2007, 2005, 2009, 2013, 2015, 2004, 2008, 2010, 2019, 2018,
#        2016, 2003, 2011, 2012, 2017, 2006, 2022, 2014, 2021])

# %%
df['price']
# Out:
# 0           $966
# 1           $142
# 2           $620
# 4           $204
# 5           $577
#            ...
# 102038      $570
# 102039      $665
# 102040      $982
# 102050        NaN
# 102057    $1,128
# Name: price, Length: 100627, dtype: object

# %%
df = df.dropna(subset = ['price'])

# %%
df['price'] = df['price'].str.replace('$', '')

# %%
df['price'] = df['price'].str.replace(',', '')

# %%
df['price'] = df['price'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100397 entries, 0 to 102057
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              100397 non-null  int64
#  1   NAME                            100397 non-null  object
#  2   host id                         100397 non-null  int64
#  3   host_identity_verified          100141 non-null  object
#  4   host name                       100397 non-null  object
#  5   neighbourhood group             100376 non-null  object
#  6   neighbourhood                   100397 non-null  object
#  7   lat                             100397 non-null  float64
#  8   long                            100397 non-null  float64
#  9   room type                       100397 non-null  object
#  10  Construction year               100397 non-null  int64
#  11  price                           100397 non-null  int64
# ...

# %%
df['price'].unique()
# Out:
# array([966, 142, 620, ..., 905, 309, 770])

# %%
df['minimum nights'].unique()
# Out:
# array([ 1.000e+01,  3.000e+01,  3.000e+00,  4.500e+01,  2.000e+00,
#         1.000e+00,  5.000e+00,  4.000e+00,  9.000e+01,  6.000e+01,
#         7.000e+00,        nan,  9.000e+00,  3.100e+01,  6.000e+00,
#         1.500e+01,  8.000e+00,  4.700e+01,  8.100e+01,  1.440e+02,
#         3.710e+02,  1.490e+02,  2.730e+02,  1.310e+02,  2.750e+02,
#         3.230e+02,  5.900e+01,  9.900e+01,  2.680e+02, -1.000e+01,
#         1.890e+02,  3.400e+02,  1.280e+02,  3.500e+02,  1.660e+02,
#         1.100e+02,  1.420e+02,  3.660e+02,  1.400e+01,  2.000e+02,
#         5.000e+01,  3.990e+02,  1.100e+01,  4.520e+02,  1.300e+01,
#         3.455e+03,  2.100e+01,  2.700e+01,  1.800e+01, -1.000e+00,
#         2.000e+01, -1.200e+01,  4.000e+01,  4.400e+01,  3.980e+02,
#        -2.000e+00,  2.800e+01,  6.500e+01, -3.000e+00,  2.900e+01,
#         5.500e+01,  1.200e+02,  3.650e+02,  1.800e+02,  1.220e+02,
#         1.900e+01,  2.400e+02,  8.800e+01,  1.150e+02,  1.500e+02,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100397 entries, 0 to 102057
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              100397 non-null  int64
#  1   NAME                            100397 non-null  object
#  2   host id                         100397 non-null  int64
#  3   host_identity_verified          100141 non-null  object
#  4   host name                       100397 non-null  object
#  5   neighbourhood group             100376 non-null  object
#  6   neighbourhood                   100397 non-null  object
#  7   lat                             100397 non-null  float64
#  8   long                            100397 non-null  float64
#  9   room type                       100397 non-null  object
#  10  Construction year               100397 non-null  int64
#  11  price                           100397 non-null  int64
# ...

# %%
df = df.dropna(subset = ['minimum nights'])

# %%
df['minimum nights'].unique()
# Out:
# array([ 1.000e+01,  3.000e+01,  3.000e+00,  4.500e+01,  2.000e+00,
#         1.000e+00,  5.000e+00,  4.000e+00,  9.000e+01,  6.000e+01,
#         7.000e+00,  9.000e+00,  3.100e+01,  6.000e+00,  1.500e+01,
#         8.000e+00,  4.700e+01,  8.100e+01,  1.440e+02,  3.710e+02,
#         1.490e+02,  2.730e+02,  1.310e+02,  2.750e+02,  3.230e+02,
#         5.900e+01,  9.900e+01,  2.680e+02, -1.000e+01,  1.890e+02,
#         3.400e+02,  1.280e+02,  3.500e+02,  1.660e+02,  1.100e+02,
#         1.420e+02,  3.660e+02,  1.400e+01,  2.000e+02,  5.000e+01,
#         3.990e+02,  1.100e+01,  4.520e+02,  1.300e+01,  3.455e+03,
#         2.100e+01,  2.700e+01,  1.800e+01, -1.000e+00,  2.000e+01,
#        -1.200e+01,  4.000e+01,  4.400e+01,  3.980e+02, -2.000e+00,
#         2.800e+01,  6.500e+01, -3.000e+00,  2.900e+01,  5.500e+01,
#         1.200e+02,  3.650e+02,  1.800e+02,  1.220e+02,  1.900e+01,
#         2.400e+02,  8.800e+01,  1.150e+02,  1.500e+02,  3.700e+02,
# ...

# %%
df[df['minimum nights'] > 0]
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 2        1002403               THEVILLAGEOFHARLEM....NEWYORK  78829239556
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# ...          ...                                         ...          ...
# 102037  57356371                                 BxApartment  11038605149
# 102038  57356923                    HUGEBEDROOMLORIMERLTRAIN  29320426760
# 102039  57357476    SpacioustwobedroomscondoinupperManhattan  14430571516
# 102040  57358028                      RoominQueensNYnearLGA.  56457739998
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  neighbourhood  \
# ...

# %%
df
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 2        1002403               THEVILLAGEOFHARLEM....NEWYORK  78829239556
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# ...          ...                                         ...          ...
# 102037  57356371                                 BxApartment  11038605149
# 102038  57356923                    HUGEBEDROOMLORIMERLTRAIN  29320426760
# 102039  57357476    SpacioustwobedroomscondoinupperManhattan  14430571516
# 102040  57358028                      RoominQueensNYnearLGA.  56457739998
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  neighbourhood  \
# ...

# %%
df['number of reviews']
# Out:
# 0           9.0
# 1          45.0
# 2           0.0
# 4           9.0
# 5          74.0
#           ...
# 102037      0.0
# 102038     17.0
# 102039     49.0
# 102040    239.0
# 102057     22.0
# Name: number of reviews, Length: 100021, dtype: float64

# %%
df['number of reviews'].unique()
# Out:
# array([9.000e+00, 4.500e+01, 0.000e+00, 7.400e+01, 4.900e+01, 4.300e+02,
#        1.180e+02, 1.600e+02, 5.300e+01, 1.670e+02, 1.130e+02, 2.700e+01,
#        1.680e+02, 2.310e+02, 2.140e+02, 2.450e+02, 1.500e+01, 2.500e+01,
#        8.100e+01, 9.700e+01, 1.050e+02, 1.910e+02, 4.000e+00, 3.380e+02,
#        1.480e+02, 1.060e+02, 1.900e+02, 2.300e+01, 2.100e+01, 1.420e+02,
#        1.430e+02, 5.400e+01, 7.000e+01, 1.600e+01, 9.400e+01, 6.100e+01,
#        1.940e+02, 2.000e+00, 1.740e+02, 2.400e+01, 1.660e+02, 2.900e+01,
#        1.700e+02, 1.900e+01, 3.340e+02, 1.200e+01, 4.670e+02, 7.000e+00,
#        3.800e+01, 3.240e+02, 1.950e+02, 1.300e+01, 3.600e+01, 6.300e+01,
#        1.550e+02, 2.600e+02, 7.300e+01, 1.930e+02, 2.000e+02, 7.900e+01,
#        3.400e+01, 1.400e+01, 8.000e+01, 2.940e+02, 1.500e+02, 4.700e+01,
#        2.190e+02, 8.400e+01, 1.140e+02, 2.130e+02, 8.600e+01, 1.800e+01,
#        2.060e+02, 1.000e+01, 1.220e+02, 5.200e+01, 1.260e+02, 1.380e+02,
# ...

# %%
df = df.dropna(subset = ['number of reviews'])

# %%
df['number of reviews'].unique()
# Out:
# array([9.000e+00, 4.500e+01, 0.000e+00, 7.400e+01, 4.900e+01, 4.300e+02,
#        1.180e+02, 1.600e+02, 5.300e+01, 1.670e+02, 1.130e+02, 2.700e+01,
#        1.680e+02, 2.310e+02, 2.140e+02, 2.450e+02, 1.500e+01, 2.500e+01,
#        8.100e+01, 9.700e+01, 1.050e+02, 1.910e+02, 4.000e+00, 3.380e+02,
#        1.480e+02, 1.060e+02, 1.900e+02, 2.300e+01, 2.100e+01, 1.420e+02,
#        1.430e+02, 5.400e+01, 7.000e+01, 1.600e+01, 9.400e+01, 6.100e+01,
#        1.940e+02, 2.000e+00, 1.740e+02, 2.400e+01, 1.660e+02, 2.900e+01,
#        1.700e+02, 1.900e+01, 3.340e+02, 1.200e+01, 4.670e+02, 7.000e+00,
#        3.800e+01, 3.240e+02, 1.950e+02, 1.300e+01, 3.600e+01, 6.300e+01,
#        1.550e+02, 2.600e+02, 7.300e+01, 1.930e+02, 2.000e+02, 7.900e+01,
#        3.400e+01, 1.400e+01, 8.000e+01, 2.940e+02, 1.500e+02, 4.700e+01,
#        2.190e+02, 8.400e+01, 1.140e+02, 2.130e+02, 8.600e+01, 1.800e+01,
#        2.060e+02, 1.000e+01, 1.220e+02, 5.200e+01, 1.260e+02, 1.380e+02,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99841 entries, 0 to 102057
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              99841 non-null  int64
#  1   NAME                            99841 non-null  object
#  2   host id                         99841 non-null  int64
#  3   host_identity_verified          99587 non-null  object
#  4   host name                       99841 non-null  object
#  5   neighbourhood group             99820 non-null  object
#  6   neighbourhood                   99841 non-null  object
#  7   lat                             99841 non-null  float64
#  8   long                            99841 non-null  float64
#  9   room type                       99841 non-null  object
#  10  Construction year               99841 non-null  int64
#  11  price                           99841 non-null  int64
# ...

# %%
df['last review'].unique()
# Out:
# array(['10/19/2021', '5/21/2022', nan, ..., '2/24/2020', '9/20/2015',
#        '4/15/2014'], dtype=object)

# %%
df = df.dropna(subset = ['last review'])

# %%
df['last review']
# Out:
# 0         10/19/2021
# 1          5/21/2022
# 4         11/19/2018
# 5          6/22/2019
# 6          10/5/2017
#              ...
# 102036    10/21/2017
# 102038     4/30/2019
# 102039     5/23/2019
# 102040     6/29/2019
# 102057     6/15/2019
# Name: last review, Length: 84404, dtype: object

# %%
df['last review'] = df['last review'].str.replace('-', '/')

# %%
df['last review'].unique()
# Out:
# array(['10/19/2021', '5/21/2022', '11/19/2018', ..., '2/24/2020',
#        '9/20/2015', '4/15/2014'], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df['availability 365'].unique()
# Out:
# array([ 2.860e+02,  2.280e+02,  2.890e+02,  3.740e+02,  2.240e+02,
#         2.190e+02,  1.800e+02,  3.750e+02,  1.000e+00,  1.630e+02,
#         4.700e+01,  6.800e+01,  1.000e+02,  7.600e+01,  4.160e+02,
#         2.140e+02,  1.100e+02,  3.540e+02,  3.300e+01,  4.050e+02,
#         8.600e+01,  1.520e+02,        nan,  8.200e+01,  8.300e+01,
#         2.580e+02,  4.000e+02,  3.400e+01,  2.030e+02,  2.800e+02,
#         4.170e+02,  1.620e+02,  1.690e+02,  1.730e+02,  1.460e+02,
#         2.430e+02,  4.250e+02,  1.130e+02,  2.600e+02,  3.950e+02,
#         2.660e+02,  5.800e+01,  4.100e+02,  3.880e+02,  1.300e+01,
#         6.200e+01,  3.340e+02,  1.660e+02,  1.800e+01,  1.300e+02,
#         4.300e+01,  1.900e+02,  3.350e+02,  5.200e+01,  7.000e+01,
#         3.110e+02,  1.410e+02, -1.000e+00,  2.630e+02,  2.000e+02,
#         1.440e+02,  3.200e+02,  1.900e+01,  2.930e+02,  2.400e+02,
#         9.600e+01,  3.000e+02,  3.320e+02,  1.380e+02,  3.270e+02,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84404 entries, 0 to 102057
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              84404 non-null  int64
#  1   NAME                            84404 non-null  object
#  2   host id                         84404 non-null  int64
#  3   host_identity_verified          84190 non-null  object
#  4   host name                       84404 non-null  object
#  5   neighbourhood group             84387 non-null  object
#  6   neighbourhood                   84404 non-null  object
#  7   lat                             84404 non-null  float64
#  8   long                            84404 non-null  float64
#  9   room type                       84404 non-null  object
#  10  Construction year               84404 non-null  int64
#  11  price                           84404 non-null  int64
# ...

# %%
df = df.dropna(subset = ['availability 365'])

# %%
df[df['availability 365'] < 365]
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 6        1004650                              BlissArtsSpace  61300605564
# 7        1005202                              BlissArtsSpace  90821839709
# ...          ...                                         ...          ...
# 102036  57355819          PrivateRoominBrooklynCommunalHouse  39435056937
# 102038  57356923                    HUGEBEDROOMLORIMERLTRAIN  29320426760
# 102039  57357476    SpacioustwobedroomscondoinupperManhattan  14430571516
# 102040  57358028                      RoominQueensNYnearLGA.  56457739998
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                                    0
# NAME                                  0
# host id                               0
# host_identity_verified              210
# host name                             0
# neighbourhood group                   9
# neighbourhood                         0
# lat                                   0
# long                                  0
# room type                             0
# Construction year                     0
# price                                 0
# service fee                         207
# minimum nights                        0
# number of reviews                     0
# last review                           0
# reviews per month                     9
# review rate number                  242
# calculated host listings count      258
# availability 365                      0
# house_rules                       44458
# license                           84277
# dtype: int64

# %%
df['reviews per month']
# Out:
# 0         0.21
# 1         0.38
# 4         0.10
# 5         0.59
# 6         0.40
#           ...
# 102036    0.57
# 102038    0.61
# 102039    1.81
# 102040    8.58
# 102057    0.85
# Name: reviews per month, Length: 84279, dtype: float64

# %%
df['reviews per month'].unique()
# Out:
# array([ 0.21,  0.38,  0.1 , ..., 24.49, 33.08, 10.37])

# %%
df = df.dropna(subset = ['reviews per month'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84270 entries, 0 to 102057
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              84270 non-null  int64
#  1   NAME                            84270 non-null  object
#  2   host id                         84270 non-null  int64
#  3   host_identity_verified          84063 non-null  object
#  4   host name                       84270 non-null  object
#  5   neighbourhood group             84262 non-null  object
#  6   neighbourhood                   84270 non-null  object
#  7   lat                             84270 non-null  float64
#  8   long                            84270 non-null  float64
#  9   room type                       84270 non-null  object
#  10  Construction year               84270 non-null  int64
#  11  price                           84270 non-null  int64
# ...

# %%
df[df['reviews per month'] < 0]
# Out:
# Empty DataFrame
# Columns: [id, NAME, host id, host_identity_verified, host name, neighbourhood group, neighbourhood, lat, long, room type, Construction year, price, service fee, minimum nights, number of reviews, last review, reviews per month, review rate number, calculated host listings count, availability 365, house_rules, license]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84270 entries, 0 to 102057
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              84270 non-null  int64
#  1   NAME                            84270 non-null  object
#  2   host id                         84270 non-null  int64
#  3   host_identity_verified          84063 non-null  object
#  4   host name                       84270 non-null  object
#  5   neighbourhood group             84262 non-null  object
#  6   neighbourhood                   84270 non-null  object
#  7   lat                             84270 non-null  float64
#  8   long                            84270 non-null  float64
#  9   room type                       84270 non-null  object
#  10  Construction year               84270 non-null  int64
#  11  price                           84270 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# NAME                                  0
# host id                               0
# host_identity_verified              207
# host name                             0
# neighbourhood group                   8
# neighbourhood                         0
# lat                                   0
# long                                  0
# room type                             0
# Construction year                     0
# price                                 0
# service fee                         207
# minimum nights                        0
# number of reviews                     0
# last review                           0
# reviews per month                     0
# review rate number                  242
# calculated host listings count      258
# availability 365                      0
# house_rules                       44455
# license                           84268
# dtype: int64

# %%
df = df.drop(columns = ['host_identity_verified', 'service fee', 'review rate number', 'calculated host listings count', 'house_rules', 'license'])

# %%
df
# Out:
#               id                                        NAME      host id  \
# 0        1001254                  Cleanquietapthomebythepark  80014485718
# 1        1002102                         SkylitMidtownCastle  52335172823
# 4        1003689  EntireApt:SpaciousStudio/Loftbycentralpark  92037596077
# 5        1004098          LargeCozy1BRApartmentInMidtownEast  45498551794
# 6        1004650                              BlissArtsSpace  61300605564
# ...          ...                                         ...          ...
# 102036  57355819          PrivateRoominBrooklynCommunalHouse  39435056937
# 102038  57356923                    HUGEBEDROOMLORIMERLTRAIN  29320426760
# 102039  57357476    SpacioustwobedroomscondoinupperManhattan  14430571516
# 102040  57358028                      RoominQueensNYnearLGA.  56457739998
# 102057  57367417                              RosaleeStewart  93578954226
#
#        host name neighbourhood group       neighbourhood       lat      long  \
# ...
